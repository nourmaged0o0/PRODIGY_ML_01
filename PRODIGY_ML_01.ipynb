# %% [markdown]
# <a href="https://colab.research.google.com/github/nourmaged0o0/PRODIGY_ML_01/blob/main/PRODIGY_ML_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import trainning data

# %%
import pandas as pd
data = pd.read_csv('/content/train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Use necessary columns

# %%
data = data[['BedroomAbvGr', 'FullBath', 'HalfBath', 'GrLivArea', 'LotArea', 'SalePrice']]

# %%
data.head()
# Out:
#    BedroomAbvGr  FullBath  HalfBath  GrLivArea  LotArea  SalePrice
# 0             3         2         1       1710     8450     208500
# 1             3         2         0       1262     9600     181500
# 2             3         2         1       1786    11250     223500
# 3             3         1         0       1717     9550     140000
# 4             4         2         1       2198    14260     250000

# %%
data.shape
# Out:
# (1460, 6)

# %% [markdown]
# # Check if there is a outlayers

# %%
data['BedroomAbvGr'].value_counts()
data['FullBath'].value_counts()
# Out:
# FullBath
# 2    768
# 1    650
# 3     33
# 0      9
# Name: count, dtype: int64

# %% [markdown]
# # Split training data to features and labels

# %%
x = data.iloc[:,0:5]
y = data.iloc[:,5:6]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaleX= MinMaxScaler()
scaleY= MinMaxScaler()
x = scaleX.fit_transform(x)
y = scaleY.fit_transform(y)

# %% [markdown]
# # Build the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=80)
reg = LinearRegression()
reg.fit(x_train,y_train)

score = cross_val_score(reg,x,y,cv=5)
score.mean()
# Out:
# 0.5809191471990738

# %% [markdown]
# # Import testing data

# %%
data2 = pd.read_csv('/content/test.csv')
data2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# # Use necessary columns

# %%
data2=data2[['BedroomAbvGr', 'FullBath', 'HalfBath', 'GrLivArea', 'LotArea']]
data2.head()
# Out:
#    BedroomAbvGr  FullBath  HalfBath  GrLivArea  LotArea
# 0             2         1         0        896    11622
# 1             3         1         1       1329    14267
# 2             3         2         1       1629    13830
# 3             3         2         1       1604     9978
# 4             2         2         0       1280     5005

# %% [markdown]
# # Scale the features of TestingData

# %%
x2=data2.copy()
x2 = scaleX.fit_transform(x2)

# %% [markdown]
# # Use the model to predict the prices of testing data

# %%
y2 = reg.predict(x2)

# %% [markdown]
# # Inverse scaling from predicted prices

# %%
answer = scaleY.inverse_transform(y2)
answer
# Out:
# array([[113738.81987026],
#        [140638.45488406],
#        [199405.41036625],
#        ...,
#        [102921.34290002],
#        [ 83963.69472458],
#        [230056.32602302]])

# %% [markdown]
# # Add price column to new data

# %%
data2['SalePrice']=answer
data2.head()
# Out:
#    BedroomAbvGr  FullBath  HalfBath  GrLivArea  LotArea      SalePrice
# 0             2         1         0        896    11622  113738.819870
# 1             3         1         1       1329    14267  140638.454884
# 2             3         2         1       1629    13830  199405.410366
# 3             3         2         1       1604     9978  186382.667738
# 4             2         2         0       1280     5005  165591.693269

# %% [markdown]
# # Export new TestingData with predicted prices column

# %%
data2.to_csv('predicted_prices.csv',index=False)
